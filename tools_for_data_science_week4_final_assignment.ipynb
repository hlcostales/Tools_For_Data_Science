# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Harold L. Costales** <br>
# Researcher

# %% [markdown]
# I am interested in Data Science because it is challenging and rewarding.

# %% [markdown]
# ### The code below will display the text 'Thank You IBM Skills Network!'

# %%
print('Thank You IBM Skills Network!')
# Out:
# Thank You IBM Skills Network!

# %% [markdown]
# ***
#
# *   Apples
# *   Bananas
#
# 1.   Red
# 2.   Green <br>
# [link text](https://www.google.com)
#
# ![CCIT-300x300.png](data:image/png;base64,...)
